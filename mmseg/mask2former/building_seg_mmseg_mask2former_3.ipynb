# %% [markdown]
# 버전 확인 및 라이브러리 설치

# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
# Copyright (C) 2019 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0xffffffff
# cpu MHz		: 2299.998
# cache size	: 46080 KB
# physical id	: 0

# %%
# !nvidia-smi
# Out:
# Wed Jul 19 10:27:58 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install MMCV
# !pip install -U openmim
# !mim install mmengine
# !mim install "mmcv>=2.0.0rc1"
# !pip install "mmdet>=3.0.0rc4"
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.4)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.9-py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.27.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.4.3)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 37.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Installing collected packages: pycryptodome, ordered-set, colorama, model-index, opendatalab, openmim
# Successfully installed colorama-0.4.6 model-index-0.1.11 opendatalab-0.0.9 openmim-0.3.9 ordered-set-4.1.0 pycryptodome-3.18.0
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.8.2-py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 10.0 MB/s eta 0:00:00
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.3.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.14.0)
# Collecting importlib-metadata>=6.6.0 (from yapf->mmengine)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (3.8.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Installing collected packages: addict, importlib-metadata, yapf, mmengine
# Successfully installed addict-2.4.0 importlib-metadata-6.8.0 mmengine-0.8.2 yapf-0.40.1
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.1-cp310-cp310-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.40.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.3.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (6.8.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (3.8.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0rc1) (3.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.1
# Collecting mmdet>=3.0.0rc4
#   Downloading mmdet-3.1.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (1.22.4)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (2.0.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (1.10.1)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (2.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from mmdet>=3.0.0rc4) (1.16.0)
# Collecting terminaltables (from mmdet>=3.0.0rc4)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmdet>=3.0.0rc4) (2.8.2)
# Installing collected packages: terminaltables, mmdet
# Successfully installed mmdet-3.1.0 terminaltables-3.1.10

# %%
# !rm -rf mmsegmentation
# !git clone https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation
# !pip install -e .
# Out:
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 15727, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 15727 (delta 27), reused 79 (delta 16), pack-reused 15625
# Receiving objects: 100% (15727/15727), 20.95 MiB | 39.08 MiB/s, done.
# Resolving deltas: 100% (11037/11037), done.
# /content/mmsegmentation
# Obtaining file:///content/mmsegmentation
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (23.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (0.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.1.0) (1.16.0)
# Installing collected packages: mmsegmentation
#   Running setup.py develop for mmsegmentation
# Successfully installed mmsegmentation-1.1.0

# %%
# %cd mmsegmentation
# Out:
# /content/mmsegmentation

# %%
import os
import os.path as osp
import shutil

from tqdm.auto import tqdm
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch, torchvision

import mmcv
import mmseg

# %%
print(torch.__version__, torch.cuda.is_available())
print(mmseg.__version__)
# Out:
# 2.0.1+cu118 True
# 1.1.0

# %% [markdown]
# 데이터 압축해제 및 폴더 생성

# %%
# !unzip -qq /content/drive/MyDrive/data.zip

# %%
def rle_decode(mask_rle, shape):
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    img = img.reshape(shape)
    return img

# RLE 인코딩 함수
def rle_encode(mask):

    pixels = mask.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset, MultiImageMixDataset

@DATASETS.register_module()
class BuildingSegDataset(BaseSegDataset):
  METAINFO = dict(
      classes=("bg", "building"),
      palette=([128, 0, 0], [0, 128, 0])
  )
  def __init__(self,
               img_suffix=".png",
               seg_map_suffix=".png",
               **kwargs):
    super().__init__(
        img_suffix=img_suffix,
        seg_map_suffix=seg_map_suffix,
        **kwargs)

# %% [markdown]
# Creat Config File

# %%
from mmengine import Config
cfg = Config.fromfile('configs/mask2former/mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024.py')
# print(f'Config:\n{cfg.pretty_text}')

# %%
# mask2former
epoch = 60
data_root = "data"
cfg.num_classes = 2

# cfg.load_from = "/content/drive/MyDrive/best_mIoU_iter_21450.pth"
# cfg.resume = True

cfg.model.decode_head.num_classes = cfg.num_classes
cfg.model.decode_head.out_channels = 2
# cfg.model.decode_head.loss_cls.use_sigmoid = True

cfg.model.decode_head.loss_cls = dict(
            type='mmdet.CrossEntropyLoss',
            use_sigmoid=False,
            loss_weight=2.0,
            reduction='mean',
            class_weight=[0.5, 1.0] + [0.1])

# Modify dataset type and path
cfg.dataset_type = 'BuildingSegDataset'
cfg.data_root = data_root
cfg.crop_size = (512, 512)

# train : 7141 * 0.8 -> 5713
# 5713 / 8 -> 1429 iter == 1 epoch

cfg.train_cfg.type = "IterBasedTrainLoop"
cfg.train_cfg.max_iters = 1429 * epoch
cfg.train_cfg.val_interval = 1429 * 3

cfg.default_hooks.logger.interval = 1000
cfg.default_hooks.checkpoint.interval = 1429 * 3
cfg.default_hooks.checkpoint.max_keep_ckpts = 5

cfg.optim_wrapper.type = "AmpOptimWrapper"
cfg.optim_wrapper.accumulative_counts = 2

cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', reduce_zero_label=False),
    dict(
        type='RandomChoiceResize',
        scales=[int(1024 * x * 0.1) for x in range(5, 21)],
        resize_type='ResizeShortestEdge',
        max_size=4096),
    dict(type="RandomCutOut", prob=0.5, n_holes=(1, 4), cutout_shape=[(size, size) for size in [50, 100, 200, 300]]),
    dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(type='PackSegInputs'),
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(512, 512), keep_ratio=True),
    dict(type='LoadAnnotations', reduce_zero_label=False),
    dict(type='PackSegInputs'),
]


cfg.train_dataloader.num_workers = 3
cfg.train_dataloader.batch_size = 2
cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.data_prefix = dict(img_path="images/train", seg_map_path="annotations/train")


cfg.val_dataloader.num_workers = 3
cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.data_prefix = dict(img_path="images/val", seg_map_path="annotations/val")

cfg.test_dataloader.num_workers = 3
cfg.test_dataloader.dataset.type = cfg.dataset_type
cfg.test_dataloader.dataset.data_root = cfg.data_root
cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.test_dataloader.dataset.data_prefix = dict(img_path="images/val", seg_map_path="annotations/val")



cfg['randomness'] = dict(seed=42)
cfg.work_dir = './work_dirs/mask2former'

print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# dataset_type = 'BuildingSegDataset'
# data_root = 'data'
# crop_size = (
#     512,
#     512,
# )
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             512,
#             614,
#             716,
#             819,
#             921,
#             1024,
#             1126,
#             1228,
#             1331,
#             1433,
#             1536,
#             1638,
#             1740,
#             1843,
#             1945,
#             2048,
#         ],
#         resize_type='ResizeShortestEdge',
#         max_size=4096),
#     dict(
#         type='RandomCutOut',
#         prob=0.5,
#         n_holes=(
#             1,
#             4,
#         ),
#         cutout_shape=[
#             (
#                 50,
#                 50,
#             ),
#             (
#                 100,
#                 100,
#             ),
#             (
#                 200,
#                 200,
#             ),
#             (
#                 300,
#                 300,
#             ),
#         ]),
#     dict(type='RandomCrop', crop_size=(
#         512,
#         512,
#     ), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(
#         512,
#         512,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(type='PackSegInputs'),
# ]
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[
#             [
#                 dict(type='Resize', scale_factor=0.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=0.75, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.0, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.25, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.75, keep_ratio=True),
#             ],
#             [
#                 dict(type='RandomFlip', prob=0.0, direction='horizontal'),
#                 dict(type='RandomFlip', prob=1.0, direction='horizontal'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ]),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/train', seg_map_path='annotations/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     512,
#                     614,
#                     716,
#                     819,
#                     921,
#                     1024,
#                     1126,
#                     1228,
#                     1331,
#                     1433,
#                     1536,
#                     1638,
#                     1740,
#                     1843,
#                     1945,
#                     2048,
#                 ],
#                 resize_type='ResizeShortestEdge',
#                 max_size=4096),
#             dict(
#                 type='RandomCutOut',
#                 prob=0.5,
#                 n_holes=(
#                     1,
#                     4,
#                 ),
#                 cutout_shape=[
#                     (
#                         50,
#                         50,
#                     ),
#                     (
#                         100,
#                         100,
#                     ),
#                     (
#                         200,
#                         200,
#                     ),
#                     (
#                         300,
#                         300,
#                     ),
#                 ]),
#             dict(
#                 type='RandomCrop', crop_size=(
#                     512,
#                     512,
#                 ), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# val_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# test_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     test_cfg=dict(size_divisor=32))
# num_classes = 2
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             1024,
#         ),
#         test_cfg=dict(size_divisor=32)),
#     backbone=dict(
#         type='SwinTransformer',
#         embed_dims=128,
#         depths=[
#             2,
#             2,
#             18,
#             2,
#         ],
#         num_heads=[
#             4,
#             8,
#             16,
#             32,
#         ],
#         window_size=12,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.3,
#         patch_norm=True,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         with_cp=False,
#         frozen_stages=-1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_base_patch4_window12_384_22k_20220317-e5c09f74.pth'
#         ),
#         pretrain_img_size=384),
#     decode_head=dict(
#         type='Mask2FormerHead',
#         in_channels=[
#             128,
#             256,
#             512,
#             1024,
#         ],
#         strides=[
#             4,
#             8,
#             16,
#             32,
#         ],
#         feat_channels=256,
#         out_channels=2,
#         num_classes=2,
#         num_queries=100,
#         num_transformer_feat_level=3,
#         align_corners=False,
#         pixel_decoder=dict(
#             type='mmdet.MSDeformAttnPixelDecoder',
#             num_outs=3,
#             norm_cfg=dict(type='GN', num_groups=32),
#             act_cfg=dict(type='ReLU'),
#             encoder=dict(
#                 num_layers=6,
#                 layer_cfg=dict(
#                     self_attn_cfg=dict(
#                         embed_dims=256,
#                         num_heads=8,
#                         num_levels=3,
#                         num_points=4,
#                         im2col_step=64,
#                         dropout=0.0,
#                         batch_first=True,
#                         norm_cfg=None,
#                         init_cfg=None),
#                     ffn_cfg=dict(
#                         embed_dims=256,
#                         feedforward_channels=1024,
#                         num_fcs=2,
#                         ffn_drop=0.0,
#                         act_cfg=dict(type='ReLU', inplace=True))),
#                 init_cfg=None),
#             positional_encoding=dict(num_feats=128, normalize=True),
#             init_cfg=None),
#         enforce_decoder_input_project=False,
#         positional_encoding=dict(num_feats=128, normalize=True),
#         transformer_decoder=dict(
#             return_intermediate=True,
#             num_layers=9,
#             layer_cfg=dict(
#                 self_attn_cfg=dict(
#                     embed_dims=256,
#                     num_heads=8,
#                     attn_drop=0.0,
#                     proj_drop=0.0,
#                     dropout_layer=None,
#                     batch_first=True),
#                 cross_attn_cfg=dict(
#                     embed_dims=256,
#                     num_heads=8,
#                     attn_drop=0.0,
#                     proj_drop=0.0,
#                     dropout_layer=None,
#                     batch_first=True),
#                 ffn_cfg=dict(
#                     embed_dims=256,
#                     feedforward_channels=2048,
#                     num_fcs=2,
#                     act_cfg=dict(type='ReLU', inplace=True),
#                     ffn_drop=0.0,
#                     dropout_layer=None,
#                     add_identity=True)),
#             init_cfg=None),
#         loss_cls=dict(
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=False,
#             loss_weight=2.0,
#             reduction='mean',
#             class_weight=[
#                 0.5,
#                 1.0,
#                 0.1,
#             ]),
#         loss_mask=dict(
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True,
#             reduction='mean',
#             loss_weight=5.0),
#         loss_dice=dict(
#             type='mmdet.DiceLoss',
#             use_sigmoid=True,
#             activate=True,
#             reduction='mean',
#             naive_dice=True,
#             eps=1.0,
#             loss_weight=5.0),
#         train_cfg=dict(
#             num_points=12544,
#             oversample_ratio=3.0,
#             importance_sample_ratio=0.75,
#             assigner=dict(
#                 type='mmdet.HungarianAssigner',
#                 match_costs=[
#                     dict(type='mmdet.ClassificationCost', weight=2.0),
#                     dict(
#                         type='mmdet.CrossEntropyLossCost',
#                         weight=5.0,
#                         use_sigmoid=True),
#                     dict(
#                         type='mmdet.DiceCost',
#                         weight=5.0,
#                         pred_act=True,
#                         eps=1.0),
#                 ]),
#             sampler=dict(type='mmdet.MaskPseudoSampler'))),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# embed_multi = dict(lr_mult=1.0, decay_mult=0.0)
# optimizer = dict(
#     type='AdamW',
#     lr=0.0001,
#     weight_decay=0.05,
#     eps=1e-08,
#     betas=(
#         0.9,
#         0.999,
#     ))
# optim_wrapper = dict(
#     type='AmpOptimWrapper',
#     optimizer=dict(
#         type='AdamW',
#         lr=0.0001,
#         weight_decay=0.05,
#         eps=1e-08,
#         betas=(
#             0.9,
#             0.999,
#         )),
#     clip_grad=dict(max_norm=0.01, norm_type=2),
#     paramwise_cfg=dict(
#         custom_keys=dict({
#             'backbone':
#             dict(lr_mult=0.1, decay_mult=1.0),
#             'query_embed':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'query_feat':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'level_embed':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'backbone.patch_embed.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'absolute_pos_embed':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'relative_position_bias_table':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.2.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.3.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.4.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.5.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.3.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.3.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.6.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.7.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.8.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.9.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.10.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.11.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.12.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.13.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.14.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.15.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.16.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.17.norm':
#             dict(lr_mult=0.1, decay_mult=0.0)
#         }),
#         norm_decay_mult=0.0),
#     accumulative_counts=2)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0,
#         power=0.9,
#         begin=0,
#         end=90000,
#         by_epoch=False),
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=85740, val_interval=4287)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1000, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         by_epoch=False,
#         interval=4287,
#         save_best='mIoU',
#         max_keep_ckpts=5),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# pretrained = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_base_patch4_window12_384_22k_20220317-e5c09f74.pth'
# depths = [
#     2,
#     2,
#     18,
#     2,
# ]
# backbone_norm_multi = dict(lr_mult=0.1, decay_mult=0.0)
# backbone_embed_multi = dict(lr_mult=0.1, decay_mult=0.0)
# custom_keys = dict({
#     'backbone':
#     dict(lr_mult=0.1, decay_mult=1.0),
#     'backbone.patch_embed.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'absolute_pos_embed':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'relative_position_bias_table':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'query_embed':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'query_feat':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'level_embed':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'backbone.stages.0.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.0.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.2.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.3.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.4.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.5.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.3.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.3.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.0.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.6.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.7.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.8.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.9.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.10.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.11.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.12.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.13.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.14.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.15.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.16.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.17.norm':
#     dict(lr_mult=0.1, decay_mult=0.0)
# })
# randomness = dict(seed=42)
# work_dir = './work_dirs/mask2former'

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 07/19 10:29:21 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Jun  7 2023, 12:45:35) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 42
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 42
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/19 10:29:22 - mmengine - INFO - Config:
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# dataset_type = 'BuildingSegDataset'
# data_root = 'data'
# crop_size = (
#     512,
#     512,
# )
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             512,
#             614,
#             716,
#             819,
#             921,
#             1024,
#             1126,
#             1228,
#             1331,
#             1433,
#             1536,
#             1638,
#             1740,
#             1843,
#             1945,
#             2048,
#         ],
#         resize_type='ResizeShortestEdge',
#         max_size=4096),
#     dict(
#         type='RandomCutOut',
#         prob=0.5,
#         n_holes=(
#             1,
#             4,
#         ),
#         cutout_shape=[
#             (
#                 50,
#                 50,
#             ),
#             (
#                 100,
#                 100,
#             ),
#             (
#                 200,
#                 200,
#             ),
#             (
#                 300,
#                 300,
#             ),
#         ]),
#     dict(type='RandomCrop', crop_size=(
#         512,
#         512,
#     ), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(
#         512,
#         512,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(type='PackSegInputs'),
# ]
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[
#             [
#                 dict(type='Resize', scale_factor=0.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=0.75, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.0, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.25, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.75, keep_ratio=True),
#             ],
#             [
#                 dict(type='RandomFlip', prob=0.0, direction='horizontal'),
#                 dict(type='RandomFlip', prob=1.0, direction='horizontal'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ]),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/train', seg_map_path='annotations/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     512,
#                     614,
#                     716,
#                     819,
#                     921,
#                     1024,
#                     1126,
#                     1228,
#                     1331,
#                     1433,
#                     1536,
#                     1638,
#                     1740,
#                     1843,
#                     1945,
#                     2048,
#                 ],
#                 resize_type='ResizeShortestEdge',
#                 max_size=4096),
#             dict(
#                 type='RandomCutOut',
#                 prob=0.5,
#                 n_holes=(
#                     1,
#                     4,
#                 ),
#                 cutout_shape=[
#                     (
#                         50,
#                         50,
#                     ),
#                     (
#                         100,
#                         100,
#                     ),
#                     (
#                         200,
#                         200,
#                     ),
#                     (
#                         300,
#                         300,
#                     ),
#                 ]),
#             dict(
#                 type='RandomCrop', crop_size=(
#                     512,
#                     512,
#                 ), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# val_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# test_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         1024,
#     ),
#     test_cfg=dict(size_divisor=32))
# num_classes = 2
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             1024,
#         ),
#         test_cfg=dict(size_divisor=32)),
#     backbone=dict(
#         type='SwinTransformer',
#         embed_dims=128,
#         depths=[
#             2,
#             2,
#             18,
#             2,
#         ],
#         num_heads=[
#             4,
#             8,
#             16,
#             32,
#         ],
#         window_size=12,
#         mlp_ratio=4,
#         qkv_bias=True,
#         qk_scale=None,
#         drop_rate=0.0,
#         attn_drop_rate=0.0,
#         drop_path_rate=0.3,
#         patch_norm=True,
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         with_cp=False,
#         frozen_stages=-1,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_base_patch4_window12_384_22k_20220317-e5c09f74.pth'
#         ),
#         pretrain_img_size=384),
#     decode_head=dict(
#         type='Mask2FormerHead',
#         in_channels=[
#             128,
#             256,
#             512,
#             1024,
#         ],
#         strides=[
#             4,
#             8,
#             16,
#             32,
#         ],
#         feat_channels=256,
#         out_channels=2,
#         num_classes=2,
#         num_queries=100,
#         num_transformer_feat_level=3,
#         align_corners=False,
#         pixel_decoder=dict(
#             type='mmdet.MSDeformAttnPixelDecoder',
#             num_outs=3,
#             norm_cfg=dict(type='GN', num_groups=32),
#             act_cfg=dict(type='ReLU'),
#             encoder=dict(
#                 num_layers=6,
#                 layer_cfg=dict(
#                     self_attn_cfg=dict(
#                         embed_dims=256,
#                         num_heads=8,
#                         num_levels=3,
#                         num_points=4,
#                         im2col_step=64,
#                         dropout=0.0,
#                         batch_first=True,
#                         norm_cfg=None,
#                         init_cfg=None),
#                     ffn_cfg=dict(
#                         embed_dims=256,
#                         feedforward_channels=1024,
#                         num_fcs=2,
#                         ffn_drop=0.0,
#                         act_cfg=dict(type='ReLU', inplace=True))),
#                 init_cfg=None),
#             positional_encoding=dict(num_feats=128, normalize=True),
#             init_cfg=None),
#         enforce_decoder_input_project=False,
#         positional_encoding=dict(num_feats=128, normalize=True),
#         transformer_decoder=dict(
#             return_intermediate=True,
#             num_layers=9,
#             layer_cfg=dict(
#                 self_attn_cfg=dict(
#                     embed_dims=256,
#                     num_heads=8,
#                     attn_drop=0.0,
#                     proj_drop=0.0,
#                     dropout_layer=None,
#                     batch_first=True),
#                 cross_attn_cfg=dict(
#                     embed_dims=256,
#                     num_heads=8,
#                     attn_drop=0.0,
#                     proj_drop=0.0,
#                     dropout_layer=None,
#                     batch_first=True),
#                 ffn_cfg=dict(
#                     embed_dims=256,
#                     feedforward_channels=2048,
#                     num_fcs=2,
#                     act_cfg=dict(type='ReLU', inplace=True),
#                     ffn_drop=0.0,
#                     dropout_layer=None,
#                     add_identity=True)),
#             init_cfg=None),
#         loss_cls=dict(
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=False,
#             loss_weight=2.0,
#             reduction='mean',
#             class_weight=[
#                 0.5,
#                 1.0,
#                 0.1,
#             ]),
#         loss_mask=dict(
#             type='mmdet.CrossEntropyLoss',
#             use_sigmoid=True,
#             reduction='mean',
#             loss_weight=5.0),
#         loss_dice=dict(
#             type='mmdet.DiceLoss',
#             use_sigmoid=True,
#             activate=True,
#             reduction='mean',
#             naive_dice=True,
#             eps=1.0,
#             loss_weight=5.0),
#         train_cfg=dict(
#             num_points=12544,
#             oversample_ratio=3.0,
#             importance_sample_ratio=0.75,
#             assigner=dict(
#                 type='mmdet.HungarianAssigner',
#                 match_costs=[
#                     dict(type='mmdet.ClassificationCost', weight=2.0),
#                     dict(
#                         type='mmdet.CrossEntropyLossCost',
#                         weight=5.0,
#                         use_sigmoid=True),
#                     dict(
#                         type='mmdet.DiceCost',
#                         weight=5.0,
#                         pred_act=True,
#                         eps=1.0),
#                 ]),
#             sampler=dict(type='mmdet.MaskPseudoSampler'))),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# embed_multi = dict(lr_mult=1.0, decay_mult=0.0)
# optimizer = dict(
#     type='AdamW',
#     lr=0.0001,
#     weight_decay=0.05,
#     eps=1e-08,
#     betas=(
#         0.9,
#         0.999,
#     ))
# optim_wrapper = dict(
#     type='AmpOptimWrapper',
#     optimizer=dict(
#         type='AdamW',
#         lr=0.0001,
#         weight_decay=0.05,
#         eps=1e-08,
#         betas=(
#             0.9,
#             0.999,
#         )),
#     clip_grad=dict(max_norm=0.01, norm_type=2),
#     paramwise_cfg=dict(
#         custom_keys=dict({
#             'backbone':
#             dict(lr_mult=0.1, decay_mult=1.0),
#             'query_embed':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'query_feat':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'level_embed':
#             dict(lr_mult=1.0, decay_mult=0.0),
#             'backbone.patch_embed.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'absolute_pos_embed':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'relative_position_bias_table':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.2.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.3.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.4.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.5.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.3.blocks.0.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.3.blocks.1.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.0.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.1.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.downsample.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.6.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.7.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.8.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.9.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.10.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.11.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.12.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.13.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.14.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.15.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.16.norm':
#             dict(lr_mult=0.1, decay_mult=0.0),
#             'backbone.stages.2.blocks.17.norm':
#             dict(lr_mult=0.1, decay_mult=0.0)
#         }),
#         norm_decay_mult=0.0),
#     accumulative_counts=2)
# param_scheduler = [
#     dict(
#         type='PolyLR',
#         eta_min=0,
#         power=0.9,
#         begin=0,
#         end=90000,
#         by_epoch=False),
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=85740, val_interval=4287)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1000, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         by_epoch=False,
#         interval=4287,
#         save_best='mIoU',
#         max_keep_ckpts=5),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# pretrained = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_base_patch4_window12_384_22k_20220317-e5c09f74.pth'
# depths = [
#     2,
#     2,
#     18,
#     2,
# ]
# backbone_norm_multi = dict(lr_mult=0.1, decay_mult=0.0)
# backbone_embed_multi = dict(lr_mult=0.1, decay_mult=0.0)
# custom_keys = dict({
#     'backbone':
#     dict(lr_mult=0.1, decay_mult=1.0),
#     'backbone.patch_embed.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'absolute_pos_embed':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'relative_position_bias_table':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'query_embed':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'query_feat':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'level_embed':
#     dict(lr_mult=1.0, decay_mult=0.0),
#     'backbone.stages.0.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.0.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.2.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.3.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.4.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.5.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.3.blocks.0.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.3.blocks.1.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.0.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.1.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.downsample.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.6.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.7.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.8.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.9.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.10.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.11.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.12.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.13.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.14.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.15.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.16.norm':
#     dict(lr_mult=0.1, decay_mult=0.0),
#     'backbone.stages.2.blocks.17.norm':
#     dict(lr_mult=0.1, decay_mult=0.0)
# })
# randomness = dict(seed=42)
# work_dir = './work_dirs/mask2former'
#
# 07/19 10:29:32 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/19 10:29:32 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /content/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
runner.train()
# Out:
# /content/mmsegmentation/mmseg/datasets/transforms/loading.py:83: UserWarning: `reduce_zero_label` will be deprecated, if you would like to ignore the zero label, please set `reduce_zero_label=True` when dataset initialized
#   warnings.warn('`reduce_zero_label` will be deprecated, '
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.reduction.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.reduction.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=1e-05
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.0
# 07/19 10:29:38 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.qkv.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.proj.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.0.0.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.weight:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.weight:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.bias:weight_decay=0.05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.ffn.layers.1.bias:decay_mult=1.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:weight_decay=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:lr_mult=0.1
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:decay_mult=0.0
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:lr=1e-05
# 07/19 10:29:39 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# ...
# 07/19 22:58:35 - mmengine - INFO - Exp name: mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20230719_102920
# 07/19 22:58:35 - mmengine - INFO - Iter(train) [83000/85740]  base_lr: 1.0041e-05 lr: 1.0041e-06  eta: 0:23:09  time: 0.5102  data_time: 0.0161  memory: 8667  loss: 9.0029  decode.loss_cls: 0.0007  decode.loss_mask: 0.4207  decode.loss_dice: 0.4785  decode.d0.loss_cls: 0.0105  decode.d0.loss_mask: 0.4084  decode.d0.loss_dice: 0.4745  decode.d1.loss_cls: 0.0012  decode.d1.loss_mask: 0.4169  decode.d1.loss_dice: 0.4860  decode.d2.loss_cls: 0.0011  decode.d2.loss_mask: 0.4173  decode.d2.loss_dice: 0.4824  decode.d3.loss_cls: 0.0008  decode.d3.loss_mask: 0.4133  decode.d3.loss_dice: 0.4781  decode.d4.loss_cls: 0.0011  decode.d4.loss_mask: 0.4240  decode.d4.loss_dice: 0.4829  decode.d5.loss_cls: 0.0008  decode.d5.loss_mask: 0.4209  decode.d5.loss_dice: 0.4830  decode.d6.loss_cls: 0.0007  decode.d6.loss_mask: 0.4084  decode.d6.loss_dice: 0.4745  decode.d7.loss_cls: 0.0011  decode.d7.loss_mask: 0.4174  decode.d7.loss_dice: 0.4896  decode.d8.loss_cls: 0.0008  decode.d8.loss_mask: 0.4172  decode.d8.loss_dice: 0.4900  grad_norm: 76.9700
# 07/19 23:06:56 - mmengine - INFO - Exp name: mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20230719_102920
# 07/19 23:06:56 - mmengine - INFO - Iter(train) [84000/85740]  base_lr: 8.7402e-06 lr: 8.7402e-07  eta: 0:14:41  time: 0.4948  data_time: 0.0156  memory: 8667  loss: 9.3135  decode.loss_cls: 0.0016  decode.loss_mask: 0.4098  decode.loss_dice: 0.5082  decode.d0.loss_cls: 0.0224  decode.d0.loss_mask: 0.4141  decode.d0.loss_dice: 0.5209  decode.d1.loss_cls: 0.0040  decode.d1.loss_mask: 0.4099  decode.d1.loss_dice: 0.5146  decode.d2.loss_cls: 0.0031  decode.d2.loss_mask: 0.4088  decode.d2.loss_dice: 0.5057  decode.d3.loss_cls: 0.0018  decode.d3.loss_mask: 0.4078  decode.d3.loss_dice: 0.5192  decode.d4.loss_cls: 0.0031  decode.d4.loss_mask: 0.4038  decode.d4.loss_dice: 0.5153  decode.d5.loss_cls: 0.0028  decode.d5.loss_mask: 0.4164  decode.d5.loss_dice: 0.5252  decode.d6.loss_cls: 0.0018  decode.d6.loss_mask: 0.4139  decode.d6.loss_dice: 0.5087  decode.d7.loss_cls: 0.0028  decode.d7.loss_mask: 0.4097  decode.d7.loss_dice: 0.5187  decode.d8.loss_cls: 0.0027  decode.d8.loss_mask: 0.4141  decode.d8.loss_dice: 0.5225  grad_norm: 51.0755
# 07/19 23:15:24 - mmengine - INFO - Exp name: mask2former_swin-b-in22k-384x384-pre_8xb2-90k_cityscapes-512x1024_20230719_102920
# 07/19 23:15:24 - mmengine - INFO - Iter(train) [85000/85740]  base_lr: 7.4175e-06 lr: 7.4175e-07  eta: 0:06:15  time: 0.4890  data_time: 0.0155  memory: 8667  loss: 9.3351  decode.loss_cls: 0.0026  decode.loss_mask: 0.3527  decode.loss_dice: 0.5797  decode.d0.loss_cls: 0.0143  decode.d0.loss_mask: 0.3516  decode.d0.loss_dice: 0.5725  decode.d1.loss_cls: 0.0027  decode.d1.loss_mask: 0.3604  decode.d1.loss_dice: 0.5764  decode.d2.loss_cls: 0.0019  decode.d2.loss_mask: 0.3545  decode.d2.loss_dice: 0.5602  decode.d3.loss_cls: 0.0031  decode.d3.loss_mask: 0.3567  decode.d3.loss_dice: 0.5855  decode.d4.loss_cls: 0.0023  decode.d4.loss_mask: 0.3562  decode.d4.loss_dice: 0.5772  decode.d5.loss_cls: 0.0022  decode.d5.loss_mask: 0.3564  decode.d5.loss_dice: 0.5629  decode.d6.loss_cls: 0.0026  decode.d6.loss_mask: 0.3496  decode.d6.loss_dice: 0.5729  decode.d7.loss_cls: 0.0023  decode.d7.loss_mask: 0.3590  decode.d7.loss_dice: 0.5792  decode.d8.loss_cls: 0.0019  decode.d8.loss_mask: 0.3562  decode.d8.loss_dice: 0.5795  grad_norm: 86.6871
# 07/19 23:21:40 - mmengine - INFO - Saving checkpoint at 85740 iterations
# 07/19 23:23:28 - mmengine - INFO - Iter(val) [1000/1428]    eta: 0:00:42  time: 0.1018  data_time: 0.0042  memory: 8667
# 07/19 23:24:10 - mmengine - INFO - per class results:
# 07/19 23:24:10 - mmengine - INFO -
# +----------+-------+-------+
# |  Class   |  IoU  |  Acc  |
# +----------+-------+-------+
# |    bg    | 97.98 | 98.82 |
# | building | 72.56 |  86.2 |
# +----------+-------+-------+
# 07/19 23:24:10 - mmengine - INFO - Iter(val) [1428/1428]    aAcc: 98.0800  mIoU: 85.2700  mAcc: 92.5100  data_time: 0.0040  time: 0.0984
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): SwinTransformer(
#     (patch_embed): PatchEmbed(
#       (adap_padding): AdaptivePadding()
#       (projection): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (drop_after_pos): Dropout(p=0.0, inplace=False)
#     (stages): ModuleList(
#       (0): SwinBlockSequence(
#         (blocks): ModuleList(
#           (0-1): 2 x SwinBlock(
#             (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (attn): ShiftWindowMSA(
#               (w_msa): WindowMSA(
#                 (qkv): Linear(in_features=128, out_features=384, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=128, out_features=128, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop): DropPath()
#             )
#             (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (ffn): FFN(
#               (layers): Sequential(
#                 (0): Sequential(
#                   (0): Linear(in_features=128, out_features=512, bias=True)
#                   (1): GELU(approximate='none')
#                   (2): Dropout(p=0.0, inplace=False)
#                 )
#                 (1): Linear(in_features=512, out_features=128, bias=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (dropout_layer): DropPath()
#               (gamma2): Identity()
#             )
#           )
#         )
#         (downsample): PatchMerging(
#           (adap_padding): AdaptivePadding()
#           (sampler): Unfold(kernel_size=(2, 2), dilation=(1, 1), padding=(0, 0), stride=(2, 2))
#           (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (reduction): Linear(in_features=512, out_features=256, bias=False)
#         )
#       )
#       (1): SwinBlockSequence(
#         (blocks): ModuleList(
#           (0-1): 2 x SwinBlock(
#             (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (attn): ShiftWindowMSA(
#               (w_msa): WindowMSA(
#                 (qkv): Linear(in_features=256, out_features=768, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=256, out_features=256, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop): DropPath()
#             )
#             (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (ffn): FFN(
#               (layers): Sequential(
#                 (0): Sequential(
#                   (0): Linear(in_features=256, out_features=1024, bias=True)
#                   (1): GELU(approximate='none')
#                   (2): Dropout(p=0.0, inplace=False)
#                 )
#                 (1): Linear(in_features=1024, out_features=256, bias=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (dropout_layer): DropPath()
#               (gamma2): Identity()
#             )
#           )
#         )
#         (downsample): PatchMerging(
#           (adap_padding): AdaptivePadding()
#           (sampler): Unfold(kernel_size=(2, 2), dilation=(1, 1), padding=(0, 0), stride=(2, 2))
#           (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (reduction): Linear(in_features=1024, out_features=512, bias=False)
#         )
#       )
#       (2): SwinBlockSequence(
#         (blocks): ModuleList(
#           (0-17): 18 x SwinBlock(
#             (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (attn): ShiftWindowMSA(
#               (w_msa): WindowMSA(
#                 (qkv): Linear(in_features=512, out_features=1536, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=512, out_features=512, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop): DropPath()
#             )
#             (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#             (ffn): FFN(
#               (layers): Sequential(
#                 (0): Sequential(
#                   (0): Linear(in_features=512, out_features=2048, bias=True)
#                   (1): GELU(approximate='none')
#                   (2): Dropout(p=0.0, inplace=False)
#                 )
#                 (1): Linear(in_features=2048, out_features=512, bias=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (dropout_layer): DropPath()
#               (gamma2): Identity()
#             )
#           )
#         )
#         (downsample): PatchMerging(
#           (adap_padding): AdaptivePadding()
#           (sampler): Unfold(kernel_size=(2, 2), dilation=(1, 1), padding=(0, 0), stride=(2, 2))
#           (norm): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#           (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#         )
#       )
#       (3): SwinBlockSequence(
#         (blocks): ModuleList(
#           (0-1): 2 x SwinBlock(
#             (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (attn): ShiftWindowMSA(
#               (w_msa): WindowMSA(
#                 (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#                 (attn_drop): Dropout(p=0.0, inplace=False)
#                 (proj): Linear(in_features=1024, out_features=1024, bias=True)
#                 (proj_drop): Dropout(p=0.0, inplace=False)
#                 (softmax): Softmax(dim=-1)
#               )
#               (drop): DropPath()
#             )
#             (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (ffn): FFN(
#               (layers): Sequential(
#                 (0): Sequential(
#                   (0): Linear(in_features=1024, out_features=4096, bias=True)
#                   (1): GELU(approximate='none')
#                   (2): Dropout(p=0.0, inplace=False)
#                 )
#                 (1): Linear(in_features=4096, out_features=1024, bias=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (dropout_layer): DropPath()
#               (gamma2): Identity()
#             )
#           )
#         )
#       )
#     )
#     (norm0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     (norm3): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_base_patch4_window12_384_22k_20220317-e5c09f74.pth'}
#   (decode_head): Mask2FormerHead(
#     (pixel_decoder): MSDeformAttnPixelDecoder(
#       (input_convs): ModuleList(
#         (0): ConvModule(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#           (gn): GroupNorm(32, 256, eps=1e-05, affine=True)
#         )
#         (1): ConvModule(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#           (gn): GroupNorm(32, 256, eps=1e-05, affine=True)
#         )
#         (2): ConvModule(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#           (gn): GroupNorm(32, 256, eps=1e-05, affine=True)
#         )
#       )
#       (encoder): Mask2FormerTransformerEncoder(
#         (layers): ModuleList(
#           (0-5): 6 x DeformableDetrTransformerEncoderLayer(
#             (self_attn): MultiScaleDeformableAttention(
#               (dropout): Dropout(p=0.0, inplace=False)
#               (sampling_offsets): Linear(in_features=256, out_features=192, bias=True)
#               (attention_weights): Linear(in_features=256, out_features=96, bias=True)
#               (value_proj): Linear(in_features=256, out_features=256, bias=True)
#               (output_proj): Linear(in_features=256, out_features=256, bias=True)
#             )
#             (ffn): FFN(
#               (layers): Sequential(
#                 (0): Sequential(
#                   (0): Linear(in_features=256, out_features=1024, bias=True)
#                   (1): ReLU(inplace=True)
#                   (2): Dropout(p=0.0, inplace=False)
#                 )
#                 (1): Linear(in_features=1024, out_features=256, bias=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (dropout_layer): Identity()
#               (gamma2): Identity()
#             )
#             (norms): ModuleList(
#               (0-1): 2 x LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             )
#           )
#         )
#       )
#       (postional_encoding): SinePositionalEncoding(num_feats=128, temperature=10000, normalize=True, scale=6.283185307179586, eps=1e-06)
#       (level_encoding): Embedding(3, 256)
#       (lateral_convs): ModuleList(
#         (0): ConvModule(
#           (conv): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (gn): GroupNorm(32, 256, eps=1e-05, affine=True)
#         )
#       )
#       (output_convs): ModuleList(
#         (0): ConvModule(
#           (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (gn): GroupNorm(32, 256, eps=1e-05, affine=True)
#           (activate): ReLU(inplace=True)
#         )
#       )
#       (mask_feature): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (transformer_decoder): Mask2FormerTransformerDecoder(
#       (layers): ModuleList(
#         (0-8): 9 x Mask2FormerTransformerDecoderLayer(
#           (self_attn): MultiheadAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (dropout_layer): Identity()
#           )
#           (cross_attn): MultiheadAttention(
#             (attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=256, out_features=256, bias=True)
#             )
#             (proj_drop): Dropout(p=0.0, inplace=False)
#             (dropout_layer): Identity()
#           )
#           (ffn): FFN(
#             (layers): Sequential(
#               (0): Sequential(
#                 (0): Linear(in_features=256, out_features=2048, bias=True)
#                 (1): ReLU(inplace=True)
#                 (2): Dropout(p=0.0, inplace=False)
#               )
#               (1): Linear(in_features=2048, out_features=256, bias=True)
#               (2): Dropout(p=0.0, inplace=False)
#             )
#             (dropout_layer): Identity()
#             (gamma2): Identity()
#           )
#           (norms): ModuleList(
#             (0-2): 3 x LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (post_norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (decoder_input_projs): ModuleList(
#       (0-2): 3 x Identity()
#     )
#     (decoder_positional_encoding): SinePositionalEncoding(num_feats=128, temperature=10000, normalize=True, scale=6.283185307179586, eps=1e-06)
#     (query_embed): Embedding(100, 256)
#     (query_feat): Embedding(100, 256)
#     (level_embed): Embedding(3, 256)
#     (cls_embed): Linear(in_features=256, out_features=3, bias=True)
#     (mask_embed): Sequential(
#       (0): Linear(in_features=256, out_features=256, bias=True)
#       (1): ReLU(inplace=True)
#       (2): Linear(in_features=256, out_features=256, bias=True)
#       (3): ReLU(inplace=True)
#       (4): Linear(in_features=256, out_features=2, bias=True)
#     )
#     (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_mask): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_dice): DiceLoss()
#   )
# )

# %% [markdown]
# inference

# %%
# !unzip -qq /content/drive/MyDrive/test_img.zip -d data/

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

# Init the model from the config and the checkpoint
checkpoint_path = './work_dirs/mask2former/best_mIoU_iter_81453.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')

img = mmcv.imread('./data/test_img/TEST_00000.png')
result = inference_model(model, img)
plt.figure(figsize=(8, 6))
vis_result = show_result_pyplot(model, img, result)
plt.imshow(mmcv.bgr2rgb(vis_result))
# Out:
# Loads checkpoint by local backend from path: ./work_dirs/mask2former/best_mIoU_iter_81453.pth
# 07/19 23:33:11 - mmengine - WARNING - `Visualizer` backend is not initialized because save_dir is None.

# %%
submit = pd.read_csv("/content/drive/MyDrive/sample_submission.csv")

# %%
mask_lst = []
for idx, row in tqdm(submit.iterrows(), total=len(submit["img_id"])):
  img = mmcv.imread(f"./data/test_img/{row['img_id']}.png")
  result = inference_model(model, img)
  mask = result.pred_sem_seg.data
  mask = mask.detach().cpu().numpy()
  mask = rle_encode(mask)
  if mask == '':
    mask = -1
  mask_lst.append(mask)
submit["mask_rle"] = mask_lst
submit.to_csv("answer.csv", index=False)
# Out:
#   0%|          | 0/60640 [00:00<?, ?it/s]
