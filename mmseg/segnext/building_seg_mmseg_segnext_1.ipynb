# %%
# Check nvcc version
# !nvcc -V
# Check GCC version
# !gcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
# Copyright (C) 2021 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# !head /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 7
# microcode	: 0xffffffff
# cpu MHz		: 2200.150
# cache size	: 39424 KB
# physical id	: 0

# %%
# !nvidia-smi
# Out:
# Thu Jul 20 12:37:31 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    47W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Install MMCV
# !pip install -U openmim
# !mim install mmengine
# !mim install "mmcv>=2.0.0rc1"
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from openmim) (8.1.4)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.9-py3-none-any.whl (29 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.10/dist-packages (from openmim) (23.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openmim) (2.27.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from model-index->openmim) (3.4.3)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatalab->openmim) (4.65.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Installing collected packages: pycryptodome, ordered-set, colorama, model-index, opendatalab, openmim
# Successfully installed colorama-0.4.6 model-index-0.1.11 opendatalab-0.0.9 openmim-0.3.9 ordered-set-4.1.0 pycryptodome-3.18.0
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.8.2-py3-none-any.whl (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.6/433.6 kB 5.9 MB/s eta 0:00:00
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmengine) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine) (2.3.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmengine) (4.7.0.72)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine) (2.14.0)
# Collecting importlib-metadata>=6.6.0 (from yapf->mmengine)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (3.8.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmengine) (3.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Installing collected packages: addict, importlib-metadata, yapf, mmengine
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
# Successfully installed addict-2.4.0 importlib-metadata-6.8.0 mmengine-0.8.2 yapf-0.40.1
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.1-cp310-cp310-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: addict in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (6.0)
# Requirement already satisfied: yapf in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (0.40.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from mmcv>=2.0.0rc1) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.3.0)
# Requirement already satisfied: importlib-metadata>=6.6.0 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (6.8.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (3.8.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->mmcv>=2.0.0rc1) (3.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv>=2.0.0rc1) (1.16.0)
# Installing collected packages: mmcv
# Successfully installed mmcv-2.0.1

# %%
# !rm -rf mmsegmentation
# !git clone https://github.com/open-mmlab/mmsegmentation.git
# %cd mmsegmentation
# !pip install -e .
# Out:
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 15734, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 15734 (delta 28), reused 79 (delta 16), pack-reused 15625
# Receiving objects: 100% (15734/15734), 20.96 MiB | 18.37 MiB/s, done.
# Resolving deltas: 100% (11038/11038), done.
# /content/mmsegmentation
# Obtaining file:///content/mmsegmentation
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (23.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (0.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmsegmentation==1.1.0) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmsegmentation==1.1.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.1.0) (1.16.0)
# Installing collected packages: mmsegmentation
#   Running setup.py develop for mmsegmentation
# Successfully installed mmsegmentation-1.1.0

# %%
# %cd mmsegmentation
# Out:
# /content/mmsegmentation

# %%
# !unzip -qq /content/drive/MyDrive/data.zip

# %%
import os
import os.path as osp
import shutil

import cv2
from tqdm.auto import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch, torchvision

import mmcv
import mmseg

# %%
print(torch.__version__, torch.cuda.is_available())
print(mmseg.__version__)
# Out:
# 2.0.1+cu118 True
# 1.1.0

# %%
def rle_decode(mask_rle, shape):
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    img = img.reshape(shape)
    return img

# RLE 인코딩 함수
def rle_encode(mask):

    pixels = mask.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset

@DATASETS.register_module()
class BuildingSegDataset(BaseSegDataset):
  METAINFO = dict(
      classes=("bg", "building"),
      palette=([128, 0, 0], [0, 128, 0])
  )
  def __init__(self,
               img_suffix=".png",
               seg_map_suffix=".png",
               **kwargs):
    super().__init__(
        img_suffix=img_suffix,
        seg_map_suffix=seg_map_suffix,
        **kwargs)

# %%
from mmengine import Config
cfg = Config.fromfile('configs/segnext/segnext_mscan-l_1xb16-adamw-160k_ade20k-512x512.py')
# print(f'Config:\n{cfg.pretty_text}')

# %%
data_root = "data"
epochs = 60

cfg.model.decode_head.num_classes = 2
# cfg.model.decode_head.out_channels = 1
# cfg.model.decode_head.threshold = 0.45
# cfg.model.decode_head.loss_decode.use_sigmoid = True
# cfg.model.decode_head.loss_decode.loss_name = "loss_bce"

# TODO
# class weight 적용
# DiceLoss, FocalLoss 변경시도해보기
# contour 추가 데이터셋 작성
cfg.model.decode_head.loss_decode = [
    dict(type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
    # dict(type="DiceLoss", loss_weight=2.0),
    dict(type='LovaszLoss', loss_weight=5.0, reduction='none')
]


# Modify dataset type and path
cfg.dataset_type = 'BuildingSegDataset'
cfg.data_root = data_root

# train : 7141 * 0.8 -> 5713
# 5713 / 16 -> 447 iter == 1 epoch

# cfg.train_cfg.type = "IterBasedTrainLoop"
cfg.train_cfg.max_iters = 447 * epochs
cfg.train_cfg.val_interval = 447 * 2

cfg.default_hooks.logger.interval = 100
cfg.default_hooks.checkpoint.interval = 447
cfg.default_hooks.checkpoint.max_keep_ckpts = 5
# cfg.default_hooks.checkpoint.save_best = True



cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', reduce_zero_label=False),
    dict(
        type='RandomResize',
        scale=(2048, 1024),
        ratio_range=(0.5, 2.0),
        keep_ratio=True
    ),
    dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
    dict(type="RandomCutOut", prob=0.5, n_holes=(1, 3), cutout_shape=[(size, size) for size in [50, 100, 150]]),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PhotoMetricDistortion'),
    dict(type='PackSegInputs'),
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(512, 512), keep_ratio=True),
    dict(type='LoadAnnotations', reduce_zero_label=False),
    dict(type='PackSegInputs'),
]

cfg.train_dataloader.num_workers = 3
cfg.train_dataloader.batch_size = 16
cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
cfg.train_dataloader.dataset.data_prefix = dict(img_path="images/train", seg_map_path="annotations/train")


cfg.val_dataloader.num_workers = 3
cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.val_dataloader.dataset.data_prefix = dict(img_path="images/val", seg_map_path="annotations/val")

cfg.test_dataloader.num_workers = 3
cfg.test_dataloader.dataset.type = cfg.dataset_type
cfg.test_dataloader.dataset.data_root = cfg.data_root
cfg.test_dataloader.dataset.pipeline = cfg.test_pipeline
cfg.test_dataloader.dataset.data_prefix = dict(img_path="images/val", seg_map_path="annotations/val")


cfg['randomness'] = dict(seed=42)
cfg.work_dir = './work_dirs/segnext'

print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(
#             0.9,
#             0.999,
#         ), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         power=1.0,
#         begin=1500,
#         end=160000,
#         eta_min=0.0,
#         by_epoch=False),
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=26820, val_interval=894)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', by_epoch=False, interval=447, max_keep_ckpts=5),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# dataset_type = 'BuildingSegDataset'
# data_root = 'data'
# crop_size = (
#     512,
#     512,
# )
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(
#         type='RandomResize',
#         scale=(
#             2048,
#             1024,
#         ),
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(
#         512,
#         512,
#     ), cat_max_ratio=0.75),
#     dict(
#         type='RandomCutOut',
#         prob=0.5,
#         n_holes=(
#             1,
#             3,
#         ),
#         cutout_shape=[
#             (
#                 50,
#                 50,
#             ),
#             (
#                 100,
#                 100,
#             ),
#             (
#                 150,
#                 150,
#             ),
#         ]),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(
#         512,
#         512,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(type='PackSegInputs'),
# ]
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[
#             [
#                 dict(type='Resize', scale_factor=0.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=0.75, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.0, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.25, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.75, keep_ratio=True),
#             ],
#             [
#                 dict(type='RandomFlip', prob=0.0, direction='horizontal'),
#                 dict(type='RandomFlip', prob=1.0, direction='horizontal'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ]),
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/train', seg_map_path='annotations/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(
#                 type='RandomResize',
#                 scale=(
#                     2048,
#                     1024,
#                 ),
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(
#                     512,
#                     512,
#                 ), cat_max_ratio=0.75),
#             dict(
#                 type='RandomCutOut',
#                 prob=0.5,
#                 n_holes=(
#                     1,
#                     3,
#                 ),
#                 cutout_shape=[
#                     (
#                         50,
#                         50,
#                     ),
#                     (
#                         100,
#                         100,
#                     ),
#                     (
#                         150,
#                         150,
#                     ),
#                 ]),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# val_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# test_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segnext/mscan_l_20230227-cef260d4.pth'
# ham_norm_cfg = dict(type='GN', num_groups=32, requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     test_cfg=dict(size_divisor=32))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         test_cfg=dict(size_divisor=32)),
#     pretrained=None,
#     backbone=dict(
#         type='MSCAN',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segnext/mscan_l_20230227-cef260d4.pth'
#         ),
#         embed_dims=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         mlp_ratios=[
#             8,
#             8,
#             4,
#             4,
#         ],
#         drop_rate=0.0,
#         drop_path_rate=0.3,
#         depths=[
#             3,
#             5,
#             27,
#             3,
#         ],
#         attention_kernel_sizes=[
#             5,
#             [
#                 1,
#                 7,
#             ],
#             [
#                 1,
#                 11,
#             ],
#             [
#                 1,
#                 21,
#             ],
#         ],
#         attention_kernel_paddings=[
#             2,
#             [
#                 0,
#                 3,
#             ],
#             [
#                 0,
#                 5,
#             ],
#             [
#                 0,
#                 10,
#             ],
#         ],
#         act_cfg=dict(type='GELU'),
#         norm_cfg=dict(type='BN', requires_grad=True)),
#     decode_head=dict(
#         type='LightHamHead',
#         in_channels=[
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             1,
#             2,
#             3,
#         ],
#         channels=1024,
#         ham_channels=1024,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='GN', num_groups=32, requires_grad=True),
#         align_corners=False,
#         loss_decode=[
#             dict(type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             dict(type='LovaszLoss', loss_weight=5.0, reduction='none'),
#         ],
#         ham_kwargs=dict(
#             MD_S=1,
#             MD_R=16,
#             train_steps=6,
#             eval_steps=7,
#             inv_t=100,
#             rand_init=True)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# randomness = dict(seed=42)
# work_dir = './work_dirs/segnext'

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 07/20 12:38:31 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.6 (main, May 29 2023, 11:10:38) [GCC 11.3.0]
#     CUDA available: True
#     numpy_random_seed: 42
#     GPU 0: NVIDIA A100-SXM4-40GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.3.0-1ubuntu1~22.04.1) 11.3.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 42
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/20 12:38:32 - mmengine - INFO - Config:
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=6e-05, betas=(
#             0.9,
#             0.999,
#         ), weight_decay=0.01),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             pos_block=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             head=dict(lr_mult=10.0))))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-06, by_epoch=False, begin=0,
#         end=1500),
#     dict(
#         type='PolyLR',
#         power=1.0,
#         begin=1500,
#         end=160000,
#         eta_min=0.0,
#         by_epoch=False),
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=26820, val_interval=894)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook', by_epoch=False, interval=447, max_keep_ckpts=5),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# dataset_type = 'BuildingSegDataset'
# data_root = 'data'
# crop_size = (
#     512,
#     512,
# )
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(
#         type='RandomResize',
#         scale=(
#             2048,
#             1024,
#         ),
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(
#         512,
#         512,
#     ), cat_max_ratio=0.75),
#     dict(
#         type='RandomCutOut',
#         prob=0.5,
#         n_holes=(
#             1,
#             3,
#         ),
#         cutout_shape=[
#             (
#                 50,
#                 50,
#             ),
#             (
#                 100,
#                 100,
#             ),
#             (
#                 150,
#                 150,
#             ),
#         ]),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(
#         512,
#         512,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', reduce_zero_label=False),
#     dict(type='PackSegInputs'),
# ]
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[
#             [
#                 dict(type='Resize', scale_factor=0.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=0.75, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.0, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.25, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.5, keep_ratio=True),
#                 dict(type='Resize', scale_factor=1.75, keep_ratio=True),
#             ],
#             [
#                 dict(type='RandomFlip', prob=0.0, direction='horizontal'),
#                 dict(type='RandomFlip', prob=1.0, direction='horizontal'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ]),
# ]
# train_dataloader = dict(
#     batch_size=16,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/train', seg_map_path='annotations/train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(
#                 type='RandomResize',
#                 scale=(
#                     2048,
#                     1024,
#                 ),
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 keep_ratio=True),
#             dict(
#                 type='RandomCrop', crop_size=(
#                     512,
#                     512,
#                 ), cat_max_ratio=0.75),
#             dict(
#                 type='RandomCutOut',
#                 prob=0.5,
#                 n_holes=(
#                     1,
#                     3,
#                 ),
#                 cutout_shape=[
#                     (
#                         50,
#                         50,
#                     ),
#                     (
#                         100,
#                         100,
#                     ),
#                     (
#                         150,
#                         150,
#                     ),
#                 ]),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=3,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='BuildingSegDataset',
#         data_root='data',
#         data_prefix=dict(
#             img_path='images/val', seg_map_path='annotations/val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(
#                 512,
#                 512,
#             ), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=False),
#             dict(type='PackSegInputs'),
#         ]))
# val_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# test_evaluator = dict(
#     type='IoUMetric', iou_metrics=[
#         'mIoU',
#     ])
# checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segnext/mscan_l_20230227-cef260d4.pth'
# ham_norm_cfg = dict(type='GN', num_groups=32, requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     test_cfg=dict(size_divisor=32))
# model = dict(
#     type='EncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         test_cfg=dict(size_divisor=32)),
#     pretrained=None,
#     backbone=dict(
#         type='MSCAN',
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segnext/mscan_l_20230227-cef260d4.pth'
#         ),
#         embed_dims=[
#             64,
#             128,
#             320,
#             512,
#         ],
#         mlp_ratios=[
#             8,
#             8,
#             4,
#             4,
#         ],
#         drop_rate=0.0,
#         drop_path_rate=0.3,
#         depths=[
#             3,
#             5,
#             27,
#             3,
#         ],
#         attention_kernel_sizes=[
#             5,
#             [
#                 1,
#                 7,
#             ],
#             [
#                 1,
#                 11,
#             ],
#             [
#                 1,
#                 21,
#             ],
#         ],
#         attention_kernel_paddings=[
#             2,
#             [
#                 0,
#                 3,
#             ],
#             [
#                 0,
#                 5,
#             ],
#             [
#                 0,
#                 10,
#             ],
#         ],
#         act_cfg=dict(type='GELU'),
#         norm_cfg=dict(type='BN', requires_grad=True)),
#     decode_head=dict(
#         type='LightHamHead',
#         in_channels=[
#             128,
#             320,
#             512,
#         ],
#         in_index=[
#             1,
#             2,
#             3,
#         ],
#         channels=1024,
#         ham_channels=1024,
#         dropout_ratio=0.1,
#         num_classes=2,
#         norm_cfg=dict(type='GN', num_groups=32, requires_grad=True),
#         align_corners=False,
#         loss_decode=[
#             dict(type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             dict(type='LovaszLoss', loss_weight=5.0, reduction='none'),
#         ],
#         ham_kwargs=dict(
#             MD_S=1,
#             MD_R=16,
#             train_steps=6,
#             eval_steps=7,
#             inv_t=100,
#             rand_init=True)),
#     train_cfg=dict(),
#     test_cfg=dict(mode='whole'))
# randomness = dict(seed=42)
# work_dir = './work_dirs/segnext'
# /usr/local/lib/python3.10/dist-packages/mmengine/utils/manager.py:113: UserWarning: <class 'mmseg.visualization.local_visualizer.SegLocalVisualizer'> instance named of visualizer has been created, the method `get_instance` should not accept any other arguments
#   warnings.warn(
# 07/20 12:38:34 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/20 12:38:34 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
runner.train()
# Out:
# /content/mmsegmentation/mmseg/datasets/transforms/loading.py:83: UserWarning: `reduce_zero_label` will be deprecated, if you would like to ignore the zero label, please set `reduce_zero_label=True` when dataset initialized
#   warnings.warn('`reduce_zero_label` will be deprecated, '
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.0.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.1.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block1.2.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed2.norm.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.0.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.1.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.2.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.3.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block2.4.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.patch_embed3.norm.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.0.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.1.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.2.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.3.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.4.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.5.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.6.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.7.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.8.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.9.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.10.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.11.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.12.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.13.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.14.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.15.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm1.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.16.norm2.bias:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.weight:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.weight:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.weight:decay_mult=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.bias:lr=6e-05
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.bias:weight_decay=0.0
# 07/20 12:38:38 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.17.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.18.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.19.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.20.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.21.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.22.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.23.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.24.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.25.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block3.26.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.norm3.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.patch_embed4.norm.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.0.norm2.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.weight:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.bias:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.bias:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm1.bias:decay_mult=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm2.weight:lr=6e-05
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm2.weight:weight_decay=0.0
# 07/20 12:38:39 - mmengine - INFO - paramwise_options -- backbone.block4.1.norm2.weight:decay_mult=0.0
# ...
# 07/20 19:38:27 - mmengine - INFO - Iter(train) [26000/26820]  base_lr: 5.0726e-05 lr: 5.0726e-05  eta: 0:12:05  time: 0.8788  data_time: 0.0319  memory: 34490  loss: 0.6988  decode.loss_ce: 0.0709  decode.loss_lovasz: 0.6279  decode.acc_seg: 98.5446
# 07/20 19:39:55 - mmengine - INFO - Iter(train) [26100/26820]  base_lr: 5.0688e-05 lr: 5.0688e-05  eta: 0:10:37  time: 0.8871  data_time: 0.0318  memory: 34490  loss: 0.6233  decode.loss_ce: 0.0625  decode.loss_lovasz: 0.5608  decode.acc_seg: 98.5953
# 07/20 19:41:24 - mmengine - INFO - Iter(train) [26200/26820]  base_lr: 5.0650e-05 lr: 5.0650e-05  eta: 0:09:08  time: 0.8814  data_time: 0.0318  memory: 34490  loss: 0.6631  decode.loss_ce: 0.0672  decode.loss_lovasz: 0.5959  decode.acc_seg: 98.7254
# 07/20 19:42:52 - mmengine - INFO - Iter(train) [26300/26820]  base_lr: 5.0612e-05 lr: 5.0612e-05  eta: 0:07:40  time: 0.8816  data_time: 0.0324  memory: 34490  loss: 0.6799  decode.loss_ce: 0.0686  decode.loss_lovasz: 0.6113  decode.acc_seg: 97.8648
# 07/20 19:43:56 - mmengine - INFO - Saving checkpoint at 26373 iterations
# 07/20 19:44:23 - mmengine - INFO - Iter(train) [26400/26820]  base_lr: 5.0574e-05 lr: 5.0574e-05  eta: 0:06:11  time: 0.8802  data_time: 0.0317  memory: 34490  loss: 0.6472  decode.loss_ce: 0.0589  decode.loss_lovasz: 0.5883  decode.acc_seg: 99.0351
# 07/20 19:45:51 - mmengine - INFO - Iter(train) [26500/26820]  base_lr: 5.0537e-05 lr: 5.0537e-05  eta: 0:04:43  time: 0.8822  data_time: 0.0338  memory: 34490  loss: 0.6742  decode.loss_ce: 0.0659  decode.loss_lovasz: 0.6083  decode.acc_seg: 99.0218
# 07/20 19:47:20 - mmengine - INFO - Iter(train) [26600/26820]  base_lr: 5.0499e-05 lr: 5.0499e-05  eta: 0:03:14  time: 0.8830  data_time: 0.0334  memory: 34490  loss: 0.7290  decode.loss_ce: 0.0629  decode.loss_lovasz: 0.6661  decode.acc_seg: 99.0051
# 07/20 19:48:48 - mmengine - INFO - Iter(train) [26700/26820]  base_lr: 5.0461e-05 lr: 5.0461e-05  eta: 0:01:46  time: 0.8782  data_time: 0.0314  memory: 34490  loss: 0.6735  decode.loss_ce: 0.0622  decode.loss_lovasz: 0.6113  decode.acc_seg: 98.0854
# 07/20 19:50:16 - mmengine - INFO - Iter(train) [26800/26820]  base_lr: 5.0423e-05 lr: 5.0423e-05  eta: 0:00:17  time: 0.8832  data_time: 0.0317  memory: 34490  loss: 0.7310  decode.loss_ce: 0.0692  decode.loss_lovasz: 0.6618  decode.acc_seg: 98.2013
# 07/20 19:50:33 - mmengine - INFO - Saving checkpoint at 26820 iterations
# 07/20 19:50:41 - mmengine - INFO - Iter(val) [ 100/1428]    eta: 0:01:08  time: 0.0507  data_time: 0.0031  memory: 34490
# 07/20 19:50:47 - mmengine - INFO - Iter(val) [ 200/1428]    eta: 0:01:02  time: 0.0524  data_time: 0.0031  memory: 812
# 07/20 19:50:52 - mmengine - INFO - Iter(val) [ 300/1428]    eta: 0:00:57  time: 0.0516  data_time: 0.0030  memory: 775
# 07/20 19:50:57 - mmengine - INFO - Iter(val) [ 400/1428]    eta: 0:00:52  time: 0.0512  data_time: 0.0032  memory: 775
# 07/20 19:51:02 - mmengine - INFO - Iter(val) [ 500/1428]    eta: 0:00:47  time: 0.0504  data_time: 0.0030  memory: 812
# 07/20 19:51:07 - mmengine - INFO - Iter(val) [ 600/1428]    eta: 0:00:41  time: 0.0507  data_time: 0.0033  memory: 775
# 07/20 19:51:12 - mmengine - INFO - Iter(val) [ 700/1428]    eta: 0:00:36  time: 0.0508  data_time: 0.0032  memory: 775
# 07/20 19:51:17 - mmengine - INFO - Iter(val) [ 800/1428]    eta: 0:00:31  time: 0.0508  data_time: 0.0032  memory: 775
# 07/20 19:51:22 - mmengine - INFO - Iter(val) [ 900/1428]    eta: 0:00:26  time: 0.0494  data_time: 0.0031  memory: 775
# 07/20 19:51:27 - mmengine - INFO - Iter(val) [1000/1428]    eta: 0:00:21  time: 0.0509  data_time: 0.0033  memory: 775
# 07/20 19:51:32 - mmengine - INFO - Iter(val) [1100/1428]    eta: 0:00:16  time: 0.0501  data_time: 0.0033  memory: 775
# 07/20 19:51:37 - mmengine - INFO - Iter(val) [1200/1428]    eta: 0:00:11  time: 0.0503  data_time: 0.0032  memory: 775
# 07/20 19:51:42 - mmengine - INFO - Iter(val) [1300/1428]    eta: 0:00:06  time: 0.0503  data_time: 0.0034  memory: 775
# 07/20 19:51:47 - mmengine - INFO - Iter(val) [1400/1428]    eta: 0:00:01  time: 0.0511  data_time: 0.0033  memory: 775
# 07/20 19:51:49 - mmengine - INFO - per class results:
# 07/20 19:51:49 - mmengine - INFO -
# +----------+-------+-------+
# |  Class   |  IoU  |  Acc  |
# +----------+-------+-------+
# |    bg    |  97.8 | 98.92 |
# | building | 69.59 | 81.56 |
# +----------+-------+-------+
# 07/20 19:51:49 - mmengine - INFO - Iter(val) [1428/1428]    aAcc: 97.9000  mIoU: 83.6900  mAcc: 90.2400  data_time: 0.0032  time: 0.0506
# EncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): MSCAN(
#     (patch_embed1): StemConv(
#       (proj): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): GELU(approximate='none')
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (block1): ModuleList(
#       (0): MSCABlock(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (attn): MSCASpatialAttention(
#           (proj_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (activation): GELU(approximate='none')
#           (spatial_gating_unit): MSCAAttention(
#             (conv0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#             (conv0_1): Conv2d(64, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=64)
#             (conv0_2): Conv2d(64, 64, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=64)
#             (conv1_1): Conv2d(64, 64, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=64)
#             (conv1_2): Conv2d(64, 64, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=64)
#             (conv2_1): Conv2d(64, 64, kernel_size=(1, 21), stride=(1, 1), padding=(0, 10), groups=64)
#             (conv2_2): Conv2d(64, 64, kernel_size=(21, 1), stride=(1, 1), padding=(10, 0), groups=64)
#             (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (proj_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (drop_path): Identity()
#         (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (mlp): Mlp(
#           (fc1): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (act): GELU(approximate='none')
#           (fc2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1-2): 2 x MSCABlock(
#         (norm1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (attn): MSCASpatialAttention(
#           (proj_1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           (activation): GELU(approximate='none')
#           (spatial_gating_unit): MSCAAttention(
#             (conv0): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=64)
#             (conv0_1): Conv2d(64, 64, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=64)
#             (conv0_2): Conv2d(64, 64, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=64)
#             (conv1_1): Conv2d(64, 64, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=64)
#             (conv1_2): Conv2d(64, 64, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=64)
#             (conv2_1): Conv2d(64, 64, kernel_size=(1, 21), stride=(1, 1), padding=(0, 10), groups=64)
#             (conv2_2): Conv2d(64, 64, kernel_size=(21, 1), stride=(1, 1), padding=(10, 0), groups=64)
#             (conv3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (proj_2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (drop_path): DropPath()
#         (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (mlp): Mlp(
#           (fc1): Conv2d(64, 512, kernel_size=(1, 1), stride=(1, 1))
#           (dwconv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512)
#           (act): GELU(approximate='none')
#           (fc2): Conv2d(512, 64, kernel_size=(1, 1), stride=(1, 1))
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm1): LayerNorm((64,), eps=1e-05, elementwise_affine=True)
#     (patch_embed2): OverlapPatchEmbed(
#       (proj): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (block2): ModuleList(
#       (0-4): 5 x MSCABlock(
#         (norm1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (attn): MSCASpatialAttention(
#           (proj_1): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           (activation): GELU(approximate='none')
#           (spatial_gating_unit): MSCAAttention(
#             (conv0): Conv2d(128, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=128)
#             (conv0_1): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=128)
#             (conv0_2): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=128)
#             (conv1_1): Conv2d(128, 128, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=128)
#             (conv1_2): Conv2d(128, 128, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=128)
#             (conv2_1): Conv2d(128, 128, kernel_size=(1, 21), stride=(1, 1), padding=(0, 10), groups=128)
#             (conv2_2): Conv2d(128, 128, kernel_size=(21, 1), stride=(1, 1), padding=(10, 0), groups=128)
#             (conv3): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (proj_2): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (drop_path): DropPath()
#         (norm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (mlp): Mlp(
#           (fc1): Conv2d(128, 1024, kernel_size=(1, 1), stride=(1, 1))
#           (dwconv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1024)
#           (act): GELU(approximate='none')
#           (fc2): Conv2d(1024, 128, kernel_size=(1, 1), stride=(1, 1))
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (patch_embed3): OverlapPatchEmbed(
#       (proj): Conv2d(128, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (block3): ModuleList(
#       (0-26): 27 x MSCABlock(
#         (norm1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (attn): MSCASpatialAttention(
#           (proj_1): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#           (activation): GELU(approximate='none')
#           (spatial_gating_unit): MSCAAttention(
#             (conv0): Conv2d(320, 320, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=320)
#             (conv0_1): Conv2d(320, 320, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=320)
#             (conv0_2): Conv2d(320, 320, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=320)
#             (conv1_1): Conv2d(320, 320, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=320)
#             (conv1_2): Conv2d(320, 320, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=320)
#             (conv2_1): Conv2d(320, 320, kernel_size=(1, 21), stride=(1, 1), padding=(0, 10), groups=320)
#             (conv2_2): Conv2d(320, 320, kernel_size=(21, 1), stride=(1, 1), padding=(10, 0), groups=320)
#             (conv3): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (proj_2): Conv2d(320, 320, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (drop_path): DropPath()
#         (norm2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (mlp): Mlp(
#           (fc1): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1))
#           (dwconv): Conv2d(1280, 1280, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1280)
#           (act): GELU(approximate='none')
#           (fc2): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1))
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm3): LayerNorm((320,), eps=1e-05, elementwise_affine=True)
#     (patch_embed4): OverlapPatchEmbed(
#       (proj): Conv2d(320, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (norm): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (block4): ModuleList(
#       (0-2): 3 x MSCABlock(
#         (norm1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (attn): MSCASpatialAttention(
#           (proj_1): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           (activation): GELU(approximate='none')
#           (spatial_gating_unit): MSCAAttention(
#             (conv0): Conv2d(512, 512, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=512)
#             (conv0_1): Conv2d(512, 512, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), groups=512)
#             (conv0_2): Conv2d(512, 512, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), groups=512)
#             (conv1_1): Conv2d(512, 512, kernel_size=(1, 11), stride=(1, 1), padding=(0, 5), groups=512)
#             (conv1_2): Conv2d(512, 512, kernel_size=(11, 1), stride=(1, 1), padding=(5, 0), groups=512)
#             (conv2_1): Conv2d(512, 512, kernel_size=(1, 21), stride=(1, 1), padding=(0, 10), groups=512)
#             (conv2_2): Conv2d(512, 512, kernel_size=(21, 1), stride=(1, 1), padding=(10, 0), groups=512)
#             (conv3): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (proj_2): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (drop_path): DropPath()
#         (norm2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (mlp): Mlp(
#           (fc1): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1))
#           (dwconv): Conv2d(2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2048)
#           (act): GELU(approximate='none')
#           (fc2): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1))
#           (drop): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (norm4): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/segnext/mscan_l_20230227-cef260d4.pth'}
#   (decode_head): LightHamHead(
#     input_transform=multiple_select, ignore_index=255, align_corners=False
#     (loss_decode): ModuleList(
#       (0): CrossEntropyLoss(avg_non_ignore=False)
#       (1): LovaszLoss()
#     )
#     (conv_seg): Conv2d(1024, 2, kernel_size=(1, 1), stride=(1, 1))
#     (dropout): Dropout2d(p=0.1, inplace=False)
#     (squeeze): ConvModule(
#       (conv): Conv2d(960, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (gn): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (activate): ReLU(inplace=True)
#     )
#     (hamburger): Hamburger(
#       (ham_in): ConvModule(
#         (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (ham): NMF2D()
#       (ham_out): ConvModule(
#         (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (gn): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       )
#     )
#     (align): ConvModule(
#       (conv): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (gn): GroupNorm(32, 1024, eps=1e-05, affine=True)
#       (activate): ReLU(inplace=True)
#     )
#   )
#   init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
# )

# %%
# !mv work_dirs/segnext/iter_26820.pth /content/drive/MyDrive/segnext_iter_26820.pth

# %%
# !unzip -qq /content/drive/MyDrive/test_img.zip -d data/

# %%
submit = pd.read_csv("/content/drive/MyDrive/sample_submission.csv")

# %%
from mmseg.apis import init_model, inference_model, show_result_pyplot

# Init the model from the config and the checkpoint
checkpoint_path = './work_dirs/segnext/best_mIoU_iter_81453.pth'
model = init_model(cfg, checkpoint_path, 'cuda:0')

img = mmcv.imread('./data/test_img/TEST_00000.png')
result = inference_model(model, img)
plt.figure(figsize=(8, 6))
vis_result = show_result_pyplot(model, img, result)
plt.imshow(mmcv.bgr2rgb(vis_result))

# %%
mask_lst = []
for idx, row in tqdm(submit.iterrows(), total=len(submit["img_id"])):
  img = mmcv.imread(f"./data/test_img/{row['img_id']}.png")
  result = inference_model(model, img)
  mask = result.pred_sem_seg.data
  mask = mask.detach().cpu().numpy()
  mask = rle_encode(mask)
  if mask == '':
    mask = -1
  mask_lst.append(mask)
submit["mask_rle"] = mask_lst
submit.to_csv("answer.csv", index=False)
